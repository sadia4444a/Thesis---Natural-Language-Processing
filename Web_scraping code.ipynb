# %% [markdown]
# # Web Scraping with beautifulSoup

# %% [markdown]
# ## local Html scraping

# %%
# !pip install beautifulsoup4

# !pip install lxml
from bs4 import BeautifulSoup

with open('home.html','r') as html_file:
    content=html_file.read()
    print(content)

soup=BeautifulSoup(content,'lxml')
print(soup.prettify())

tags = soup.find('h5')
print(tags)

tags = soup.find_all('h5')
print(tags)

courses_html_tags = soup.find_all('h5')
print(tags)

for coures in courses_html_tags:
    print(course.text)

coures_cards=soup.find_all('div', class_='card')

for coures in courses_html_tags:
    coures_name=course.h5.text
    coures_price = course.a.text.split()[-1]
    print(course_name)
    print(coures_price)

# %% [markdown]
# ## website Scraping

# %%
from bs4 import BeautifulSoup
import requests

# %%
html_text=requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation=', ).text
print(html_text)

soup=BeautifulSoup(html_text,'lxml')
jobs=soup.find('li', class_= 'clearfix job-bx wht-shd-bx')

print(jobs)


company_name = job.find('h3', class_='joblist-comp-name').text.replace(' ',' ')

print(company_name )

skill_need=job.find('span', class_='srp-skills').text.replace(' ',' ')
print(skill_need)


soup=BeautifulSoup(html_text,'lxml')
jobs=soup.find_all('li', class_= 'clearfix job-bx wht-shd-bx')

for job in jobs:
    publish_date=job.find('span', class_='sim-posted').span.text.replace(' ',' ')
    print(publish_date)
#     if publish_Date=='Posted few days ago':
    company_name = job.find('h3', class_='joblist-comp-name').text.replace(' ',' ')
    skill_need=job.find('span', class_='srp-skills').text.replace(' ',' ')
    print(f'Company Name : {company_name.strip()}')
    print(f'required Skills : {skill_need.strip()}')
    print(' \n')

# %% [markdown]
# ## features addition

# %%
from bs4 import BeautifulSoup
import requests
import time

print('put some skill that you are not familiar with')
unfamiliar_skill = input('>')
print(f'filtering out {unfamiliar_skill}')






def find_job():
    soup=BeautifulSoup(html_text,'lxml')
    jobs=soup.find_all('li', class_= 'clearfix job-bx wht-shd-bx')
    for index,job in enumerate(jobs):
        publish_date=job.find('span', class_='sim-posted').span.text.replace(' ',' ')
        if 'few' in publish_date:
            company_name = job.find('h3', class_='joblist-comp-name').text.replace(' ',' ')
            skill_need=job.find('span', class_='srp-skills').text.replace(' ',' ')
            if unfamiliar_skill not in skill_need:
                with open(f'posts/{index}.txt','w') as f:
                    f.write(f'Company Name : {company_name.strip()}\n')
                    f.write(f'required Skills : {skill_need.strip()}\n')
                    f.write(f' more_info: {more_info}\n')
            print(f'File saved : {index}')


if __name__=='__main__':
    while True:
        find_jobs()
        time_wait = 10
        print(f'Wating{ time_wait} minutes...')
        time.sleep(time_wait * 60)

# %%
print('put some skill that you are not familiar with')

unfamiliar_skill = input('>')
print(f'filtering out {unfamiliar_skill}')



soup=BeautifulSoup(html_text,'lxml')
jobs=soup.find_all('li', class_= 'clearfix job-bx wht-shd-bx')






for job in jobs:
    publish_date=job.find('span', class_='sim-posted').span.text.replace(' ',' ')
    if 'few' in publish_date:

        company_name = job.find('h3', class_='joblist-comp-name').text.replace(' ',' ')
        skill_need=job.find('span', class_='srp-skills').text.replace(' ',' ')
        more_info=job.header.h2.a['href']
        if unfamiliar_skill not in skill_need:
            print(f'Company Name : {company_name.strip()}')
            print(f'required Skills : {skill_need.strip()}')
            print(f' more_info: {more_info}')
            print(' \n')

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url='https://books.toscrape.com/catalogue/page-1.html'

# %%
response=requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
response=response.content

# %%
soup=BeautifulSoup(response,'lxml')

# %%
# soup

# %%
ol= soup.find('ol')

# %%
articles = ol.find_all('article', class_='product_pod')

# %%
import pandas as pd

# %%
books=[]
for i in range(1,51):
    url=f'https://books.toscrape.com/catalogue/page-{i}.html'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'lxml')
    ol= soup.find('ol')
    articles = ol.find_all('article', class_='product_pod')

    for article in articles:
        image=article.find('img')
        title=image.attrs['alt']
        star=article.find('p')
        star=star['class'][1]
        price=article.find('p',class_='price_color').text
        price= float(price[1:])

        books.append([title, price, star])

# %%
df = pd.DataFrame(books, columns=['Ttile','Price', 'Star Rating'])

# %%
df.to_csv('books.csv')

# %%
df.head()
# Out:
#                                    Ttile  Price Star Rating
# 0                   A Light in the Attic  51.77       Three
# 1                     Tipping the Velvet  53.74         One
# 2                             Soumission  50.10         One
# 3                          Sharp Objects  47.82        Four
# 4  Sapiens: A Brief History of Humankind  54.23        Five

# %%
df.shape
# Out:
# (1000, 3)

# %%
temp = pd.DataFrame(books, columns=['Ttile','Price', 'Star Rating'])

# %%
 pd.concat([df,fake],axis=0)

# %% [markdown]
# # web_scraping from *boom*

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import lxml

# %%
web_url='https://www.boombd.com/fake-news'

# %%
url='https://www.boombd.com/fake-news'
response=requests.get(url)
response=response.content
soup=BeautifulSoup(response,'lxml')

# %%
link_heads=soup.find_all('h4')
print(link_heads)
# Out:
# [<h4 class="font-alt normal mt-10"><a href="/fake-news/spreading-baseless-information-about-a-student-protesting-in-buet-24822">বুয়েটে আন্দোলনকারী এক ছাত্রীকে নিয়ে ভিত্তিহীন তথ্য প্রচার</a></h4>, <h4 class="font-alt normal mt-10"><a href="/fake-news/allah-written-image-frame-in-ronaldos-hand-has-been-edited-and-placed-24786">রোনালদোর হাতের ফ্রেমে 'আল্লাহ' লেখা ছবিটি এডিট করে বসানো</a></h4>, <h4 class="font-alt normal mt-10"><a href="/fake-news/the-picture-circulated-claiming-to-be-full-moon-image-is-edited-24785">পূর্ণিমার চাঁদের ছবি দাবি করে প্রচারিত ছবিটি বাস্তব নয়</a></h4>, <h4 class="font-alt normal"><a class="heading_link" href="/fake-news/open-universitys-hsc-exam-fake-routine-promoted-on-facebook-24784">উন্মুক্ত বিশ্ববিদ্যালয়ের এইচএসসি পরীক্ষার সময়সূচিটি ভুয়া </a> </h4>, <h4 class="font-alt normal"><a class="heading_link" href="/fake-news/the-viral-photo-is-not-of-the-youth-interviewed-at-the-holi-festival-24783">মারধরের ভাইরাল ছবিটি হোলি উৎসবে সাক্ষাৎকার দেয়া তরুণের নয় </a> <
# ...

# %%
links=[]
article_id=[]
for link_head in link_heads:
    tem_link=link_head.a['href']
    match = re.search(r'\D(\d+)$', tem_link)
    if match:
        number = match.group(1)
    article_id.append(number)
    links.append(tem_link)

print(links)
print(article_id)
# Out:
# ['/fake-news/spreading-baseless-information-about-a-student-protesting-in-buet-24822', '/fake-news/allah-written-image-frame-in-ronaldos-hand-has-been-edited-and-placed-24786', '/fake-news/the-picture-circulated-claiming-to-be-full-moon-image-is-edited-24785', '/fake-news/open-universitys-hsc-exam-fake-routine-promoted-on-facebook-24784', '/fake-news/the-viral-photo-is-not-of-the-youth-interviewed-at-the-holi-festival-24783', '/fake-news/propaganda-of-fake-claim-of-giving-15-thousand-taka-to-each-person-with-presidents-picture-24782', '/fake-news/spreading-misleading-information-about-fasting-in-the-name-of-japanese-scientist-yoshinori-osumi-24781', '/fake-news/pathirana-did-not-take-blessings-by-touching-dhonis-feet-on-the-field-24773', '/fake-news/the-demand-of-bkash-customers-to-give-rs-7999-salami-on-the-occasion-of-eid-is-baseless-24772', '/fake-news/fake-claim-of-pharaohs-mummy-talking-spread-on-facebook-24771', '/fake-news/spreading-misinformation-using-snopes-name-24759', '/f
# ...

# %%
# import re

# text = "/fake-news/spreading-misinformation-using-snopes-name-24759"
# match = re.search(r'\D(\d+)$', text)

# if match:
#     number = match.group(1)
#     print(number)  # Output: 24759

#     match = re.search(r'2\d+', tem_link)
#     if match:
#         number = match.group()
# Out:
# 12

# %%
news=[]
for link in links:
    match = re.search(r'\D(\d+)$', link)
    if match:
        article_id = match.group()
        match = re.search(r'(\d+)', article_id)
        if match:
            article_id = match.group()
    url= "https://www.boombd.com/" + link
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'lxml')
    data_div=soup.find('div', class_='claim-review-block mt-40 mb-40')
    datas=data_div.find_all('span', class_='value')
    value=[]
    for data in datas:
        value.append(data.text)
    claim=value[0]
    clamied_by=value[1]
    Fact_check=value[2]
    print(f' artical_id : {article_id} claim : {claim}, clamied_by: {clamied_by}, Fact check: {Fact_check}')
    news.append([article_id,claim,clamied_by,Fact_check])
# Out:
#  artical_id : 24822 claim : বুয়েট আন্দোলনে নেতৃত্ব দেওয়া নারী শিক্ষার্থী পঞ্চগড় জামায়াতের সাবেক আমির আব্দুল খালেকের ভাগ্নি।, clamied_by: Facebook Post, Fact check: False
#  artical_id : 24786 claim : রোনালদো 'আল্লাহ' লেখা ফ্রেম নিজ হাতে ধরে আছেন, clamied_by: Facebook Post, Fact check: False
#  artical_id : 24785 claim : ক্যালিফোর্নিয়া, মার্কিন যুক্তরাষ্ট্রের সেন্টিনেল রকের ঠিক পশ্চিমে ইয়োসেমাইটের দক্ষিণ দিকে অ্যাঞ্জেল জলপ্রপাতের উপর নেমে আসা একটি পূর্ণিমা।, clamied_by: Facebook post, Fact check: False
#  artical_id : 24784 claim : এইচএসসি পরীক্ষা ২০২৪ এর রুটিন প্রকাশ। (ছবি), clamied_by: Facebook post, Fact check: False
#  artical_id : 24783 claim : শিক্ষার্থীদের হাতে গণধো*লাই খেলো রঙ খেলায় উস্কানিমূলক  বক্তব্য রাখা ভাইরাল সেই নকিব আশরাফ, clamied_by: Facebook Post, Fact check: False
#  artical_id : 24782 claim : নাগরিককে ১৫ হাজার বাংলাদেশী টাকা প্রদান করা হবে বলে জানালেন রাষ্ট্রপতি, clamied_by: Facebook Post, Fact check: False
# ...

# %%
df = pd.DataFrame(news, columns=['article_id','Claim','Claimed_by', 'Fact Check'])

# %%
df.head(10)
# Out:
#   article_id                                              Claim  \
# 0      24822  বুয়েট আন্দোলনে নেতৃত্ব দেওয়া নারী শিক্ষার্থী প...
# 1      24786      রোনালদো 'আল্লাহ' লেখা ফ্রেম নিজ হাতে ধরে আছেন
# 2      24785  ক্যালিফোর্নিয়া, মার্কিন যুক্তরাষ্ট্রের সেন্টি...
# 3      24784        এইচএসসি পরীক্ষা ২০২৪ এর রুটিন প্রকাশ। (ছবি)
# 4      24783  শিক্ষার্থীদের হাতে গণধো*লাই খেলো রঙ খেলায় উস্ক...
# 5      24782  নাগরিককে ১৫ হাজার বাংলাদেশী টাকা প্রদান করা হব...
# 6      24781  রোজা নিয়ে গবেষণা করে নোবেল পেয়েছেন ইয়োশিনোরি ...
# 7      24773           ধোনির পা ছুঁয়ে আশির্বাদ নিচ্ছেন পাথিরানা
# 8      24772  পবিত্র ঈদুল ফিতর উপলক্ষ্যে বিকাশ সবাইকে ৭,৯৯৯ ...
# 9      24771                            ফেরাউনের মমি কথা বলেছে।
#
#       Claimed_by  Fact Check
# 0  Facebook Post       False
# 1  Facebook Post       False
# 2  Facebook post       False
# 3  Facebook post       False
# 4  Facebook Post       False
# 5  Facebook Post       False
# 6  Facebook Post  Misleading
# ...

# %%
import re

text = "/fake-news/spreading-misinformation-using-snopes-name-24759"
match = re.search(r'\d+', text)
if match:
    number = match.group()
    print(number)  # Output: 24759
# Out:
# 24759

# %%
link_images=soup.find_all('div', class_='mb-xs-20 col-md-4')
print(link_images)
# Out:
# [<div class="mb-xs-20 col-md-4"><div class="boom-item"><div class="boom-item-image"><div class="share-article divUrl" data-url="/fake-news/spreading-baseless-information-about-a-student-protesting-in-buet-24822"><div class="dd divUrl" data-url="https://boombd.com/n-24822"><div class="dd-a"><svg height="20" version="1.1" viewbox="0 0 32 32" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="16" cy="16" r="14" style="fill:#ffffff"></circle><path d="m 17,9 0,3.036425 -4.240229,0 c -2.057768,1.12e-4 -3.9591787,1.017571 -4.9880627,2.669149 -1.0289441,1.651676 -1.0289441,3.986635 0,5.63831 C 8.7511759,21.91098 10.521135,22.910988 12.47289,23 11.000634,22.863409 9.9998663,21.715147 10,20.343884 10,18.869754 11.169268,17.981592 12.759771,18 L 17,18 17,21.011171 25,15 Z" style="fill:#e5504d;fill-rule:evenodd"></path></svg></div><input aria-labelledby="checkbox" type="checkbox"/><div class="dd-c media-icons"><a href="http://www.facebook.com/share.php?u=https%3A%2F%2Fboombd.com%2Fn-24822
# ...

# %%
for link_image in link_images:
    link_url=link_image.find('div',class_="dd divUrl")
    print(link_url['data-url'])
# Out:
# https://boombd.com/n-24822
# https://boombd.com/n-24786
# https://boombd.com/n-24785

# %%
links=[]

for link_image in link_images:
    link_url=link_image.find('div',class_="dd divUrl")
    links.append(link_url['data-url'])
    print(link_url['data-url'])
# Out:
# https://boombd.com/n-24822
# https://boombd.com/n-24786
# https://boombd.com/n-24785

# %%
links
# Out:
# ['https://boombd.com/n-24822',
#  'https://boombd.com/n-24786',
#  'https://boombd.com/n-24785']

# %% [markdown]
# ## acces_data

# %%
# news=[]
# url='https://boombd.com/n-24822'
# response=requests.get(url)
# print(response)
# response=response.content
# soup=BeautifulSoup(response,'lxml')
# data_div=soup.find('div', class_='claim-review-block mt-40 mb-40')
# datas=data_div.find_all('span', class_='value')
# value=[]
# for data in datas:
#     value.append(data.text)

# news.append()

# %%
# df = pd.DataFrame(([value[0],value[1],value[2]]), columns=['Claim','Claimed_by', 'Fact Check'])
# df

# %%
news=[]
for link in links:
    url=link
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'lxml')
    data_div=soup.find('div', class_='claim-review-block mt-40 mb-40')
    datas=data_div.find_all('span', class_='value')
    value=[]
    for data in datas:
        value.append(data.text)
    claim=value[0]
    clamied_by=value[1]
    Fact_check=value[2]

    print(f'claim : {claim}, clamied_by: {clamied_by}, Fact check: {Fact_check}')
    news.append([claim,clamied_by,Fact_check])
# Out:
# claim : বুয়েট আন্দোলনে নেতৃত্ব দেওয়া নারী শিক্ষার্থী পঞ্চগড় জামায়াতের সাবেক আমির আব্দুল খালেকের ভাগ্নি।, clamied_by: Facebook Post, Fact check: False
# claim : রোনালদো 'আল্লাহ' লেখা ফ্রেম নিজ হাতে ধরে আছেন, clamied_by: Facebook Post, Fact check: False
# claim : ক্যালিফোর্নিয়া, মার্কিন যুক্তরাষ্ট্রের সেন্টিনেল রকের ঠিক পশ্চিমে ইয়োসেমাইটের দক্ষিণ দিকে অ্যাঞ্জেল জলপ্রপাতের উপর নেমে আসা একটি পূর্ণিমা।, clamied_by: Facebook post, Fact check: False

# %%
df = pd.DataFrame(news, columns=['Claim','Claimed_by', 'Fact Check'])

# %%
df
# Out:
#                                                Claim     Claimed_by Fact Check
# 0  বুয়েট আন্দোলনে নেতৃত্ব দেওয়া নারী শিক্ষার্থী প...  Facebook Post      False
# 1      রোনালদো 'আল্লাহ' লেখা ফ্রেম নিজ হাতে ধরে আছেন  Facebook Post      False
# 2  ক্যালিফোর্নিয়া, মার্কিন যুক্তরাষ্ট্রের সেন্টি...  Facebook post      False

# %% [markdown]
# ## dataset

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import lxml

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import lxml

final_df=pd.DataFrame()

for i in range(2,52):
    url=f'https://www.boombd.com/fake-news/{i}'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'lxml')

    link_heads=soup.find_all('h4')
    #print(link_heads)

    links=[]
    article_id=[]
    for link_head in link_heads:
        tem_link=link_head.a['href']
        match = re.search(r'\D(\d+)$', tem_link)
        if match:
            number = match.group(1)
        article_id.append(number)
        links.append(tem_link)

    #print(links)
    #print(article_id)

    news=[]
    for link in links:
        match = re.search(r'\D(\d+)$', link)
        if match:
            article_id = match.group()
            match = re.search(r'(\d+)', article_id)
            if match:
                article_id = match.group()
        url= "https://www.boombd.com/" + link
        response=requests.get(url)
        response=response.content
        soup=BeautifulSoup(response,'lxml')
        data_div=soup.find('div', class_='claim-review-block mt-40 mb-40')
        datas=data_div.find_all('span', class_='value')
        value=[]
        for data in datas:
            value.append(data.text)
        claim=value[0]
        clamied_by=value[1]
        Fact_check=value[2]
        #print(f' artical_id : {article_id} claim : {claim}, clamied_by: {clamied_by}, Fact check: {Fact_check}')
        news.append([article_id,claim,clamied_by,Fact_check])


    temp_df = pd.DataFrame(news, columns=['article_id','Claim','Claimed_by', 'Fact Check'])

    final_df_1=pd.concat([final_df_1, temp_df],axis=0)
    del temp_df
    print(f'page number {i} is completed')
    if i%10==0:
        final_df_1.to_csv('final_df_1.csv',index=False)


final_df_1.to_csv('final_df_1.csv',index=False)
# Out:
# page number 2 is completed
# page number 3 is completed
# page number 4 is completed
# page number 5 is completed
# page number 6 is completed
# page number 7 is completed
# page number 8 is completed
# page number 9 is completed
# page number 10 is completed
# page number 11 is completed
# page number 12 is completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-6016ec58593b> in <cell line: 8>()
#      41         soup=BeautifulSoup(response,'lxml')
#      42         data_div=soup.find('div', class_='claim-review-block mt-40 mb-40')
# ---> 43         datas=data_div.find_all('span', class_='value')
#      44         value=[]
#      45         for data in datas:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
len(final_df_1)
# Out:
# 144

# %%
final_df.head()
# Out:
#   article_id                                              Claim  \
# 0      24745  নারকেল ফুটানো গরম জল খেলে ক্যান্সার নিরাময় হবে...
# 1      24744                      ইনি শাহজাহান এর স্ত্রী মমতাজ।
# 2      24743  অবশেষে পাকিস্তান সুপার লিগের ফাইনাল উপভোগ করতে...
# 3      24723  ১৪ আগস্ট, ২০০৩ সালে যমুনা সেতুতে রেল চালু হওয়া...
# 4      24722  পাইলট ল্যান্ডিংয়ের ঘোষণা দিয়ে মাইক বন্ধ করতে ভ...
#
#       Claimed_by Fact Check
# 0  Facebook Post      False
# 1  Facebook post      False
# 2  Facebook Post      False
# 3  Facebook Post      False
# 4  Facebook Post      False

# %%
len(final_df)
# Out:
# 12

# %%
url=f'https://www.boombd.com/fake-news/13'
response=requests.get(url)
response=response.content
soup=BeautifulSoup(response,'lxml')

link_heads=soup.find_all('h4')
    #print(link_heads)
links=[]
article_id=[]
for link_head in link_heads:
    tem_link=link_head.a['href']
    match = re.search(r'\D(\d+)$', tem_link)
    if match:
        number = match.group(1)
        article_id.append(number)
        links.append(tem_link)

print(links)
print(article_id)

news=[]
for link in links:
    match = re.search(r'\D(\d+)$', link)
    if match:
        article_id = match.group()

    match = re.search(r'(\d+)', article_id)
    if match:
        article_id = match.group()
    url= "https://www.boombd.com/" + link
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'lxml')
    # data_div=soup.find('div', class_='claim-review-block mt-40 mb-40')
    datas=soup.find_all('span', class_='value')
    print(datas)
    value=[]
    for data in datas:
        print(data)
        value.append(data.text)

    length=len(value)
    if length==3:
        claim=value[0]
        clamied_by=value[1]
        Fact_check=value[2]
        #print(f' artical_id : {article_id} claim : {claim}, clamied_by: {clamied_by}, Fact check: {Fact_check}')
        news.append([article_id,claim,clamied_by,Fact_check])
        print(news)
    else:
        continue
# Out:
# ['/fake-news/the-video-of-the-bangladeshi-youths-boat-song-on-the-indian-idol-stage-is-edited-23991', '/fake-news/the-picture-of-shakib-is-old-23989', '/fake-news/spreading-fake-news-about-rumin-farhanas-illness-with-old-pictures-23981', '/fake-news/the-malaysian-government-did-not-give-this-palace-to-zakir-naik-23980', '/fake-news/the-video-of-chanting-bhua-bhua-towards-the-prime-minister-is-distorted-23979', '/fake-news/the-claim-that-the-brazilian-football-team-is-banned-is-untrue-23959', '/fake-news/the-information-about-cancellation-of-land-survey-project-is-not-true-23957', '/fake-news/the-us-state-department-did-not-comment-on-bnps-terrorist-activities-23956', '/fake-news/circulating-photos-of-different-people-claiming-to-be-laili-majnus-real-photos-23955', '/fake-news/the-information-about-bnp-participating-in-the-election-is-not-correct-23951', '/fake-news/a-fake-comment-spread-in-the-name-of-dr-younus-on-national-election-23950', '/fake-news/shadab-khan-did-not-leave-cricke
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import lxml

final_df_1=pd.DataFrame()

for i in range(2,50):
    url=f'https://www.boombd.com/fake-news/{i}'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'lxml')

    link_heads=soup.find_all('h4')
    #print(link_heads)

    links=[]
    article_id=[]
    for link_head in link_heads:
        tem_link=link_head.a['href']
        match = re.search(r'\D(\d+)$', tem_link)
        if match:
            number = match.group(1)
        article_id.append(number)
        links.append(tem_link)

    #print(links)
    #print(article_id)

    news=[]
    for link in links:
        match = re.search(r'\D(\d+)$', link)
        if match:
            article_id = match.group()
            match = re.search(r'(\d+)', article_id)
            if match:
                article_id = match.group()
        url= "https://www.boombd.com/" + link
        response=requests.get(url)
        response=response.content
        soup=BeautifulSoup(response,'lxml')
        # data_div=soup.find('div', class_='claim-review-block mt-40 mb-40')
        datas=soup.find_all('span', class_='value')
        value=[]
        for data in datas:
            value.append(data.text)
        length=len(value)
        if length==3:
            claim=value[0]
            clamied_by=value[1]
            Fact_check=value[2]
            news.append([article_id,claim,clamied_by,Fact_check])

        else:
            continue
    temp_df = pd.DataFrame(news, columns=['article_id','Claim','Claimed_by', 'Fact Check'])

    final_df_1=pd.concat([final_df_1, temp_df],axis=0)
    del temp_df
    print(f'page number {i} is completed')
    if i%10==0:
        final_df_1.to_csv('final_df_1.csv',index=False)


final_df_1.to_csv('final_df_1.csv',index=False)
# Out:
# page number 2 is completed
# page number 3 is completed
# page number 4 is completed
# page number 5 is completed
# page number 6 is completed
# page number 7 is completed
# page number 8 is completed
# page number 9 is completed
# page number 10 is completed
# page number 11 is completed
# page number 12 is completed
# page number 13 is completed
# page number 14 is completed
# page number 15 is completed
# page number 16 is completed
# page number 17 is completed
# page number 18 is completed
# page number 19 is completed
# page number 20 is completed
# page number 21 is completed
# page number 22 is completed
# page number 23 is completed
# page number 24 is completed
# page number 25 is completed
# page number 26 is completed
# page number 27 is completed
# page number 28 is completed
# page number 29 is completed
# page number 30 is completed
# page number 31 is completed
# page number 32 is completed
# page number 33 is completed
# page number 34 is completed
# ...

# %%
final_df_1.head()
# Out:
#   article_id                                              Claim  \
# 0      24745  নারকেল ফুটানো গরম জল খেলে ক্যান্সার নিরাময় হবে...
# 1      24744                      ইনি শাহজাহান এর স্ত্রী মমতাজ।
# 2      24743  অবশেষে পাকিস্তান সুপার লিগের ফাইনাল উপভোগ করতে...
# 3      24723  ১৪ আগস্ট, ২০০৩ সালে যমুনা সেতুতে রেল চালু হওয়া...
# 4      24722  পাইলট ল্যান্ডিংয়ের ঘোষণা দিয়ে মাইক বন্ধ করতে ভ...
#
#       Claimed_by Fact Check
# 0  Facebook Post      False
# 1  Facebook post      False
# 2  Facebook Post      False
# 3  Facebook Post      False
# 4  Facebook Post      False

# %%
len(final_df_1)
# Out:
# 569

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import lxml

final_df_2=pd.DataFrame()

for i in range(50,100):
    url=f'https://www.boombd.com/fake-news/{i}'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'lxml')

    link_heads=soup.find_all('h4')
    #print(link_heads)

    links=[]
    article_id=[]
    for link_head in link_heads:
        tem_link=link_head.a['href']
        match = re.search(r'\D(\d+)$', tem_link)
        if match:
            number = match.group(1)
        article_id.append(number)
        links.append(tem_link)

    #print(links)
    #print(article_id)

    news=[]
    for link in links:
        match = re.search(r'\D(\d+)$', link)
        if match:
            article_id = match.group()
            match = re.search(r'(\d+)', article_id)
            if match:
                article_id = match.group()
        url= "https://www.boombd.com/" + link
        response=requests.get(url)
        response=response.content
        soup=BeautifulSoup(response,'lxml')
        # data_div=soup.find('div', class_='claim-review-block mt-40 mb-40')
        datas=soup.find_all('span', class_='value')
        value=[]
        for data in datas:
            value.append(data.text)
        length=len(value)
        if length==3:
            claim=value[0]
            clamied_by=value[1]
            Fact_check=value[2]
            news.append([article_id,claim,clamied_by,Fact_check])

        else:
            continue
    temp_df = pd.DataFrame(news, columns=['article_id','Claim','Claimed_by', 'Fact Check'])

    final_df_2=pd.concat([final_df_2, temp_df],axis=0)
    del temp_df
    print(f'page number {i} is completed')
    if i%10==0:
        final_df_2.to_csv('final_df_2.csv',index=False)


final_df_2.to_csv('final_df_2.csv',index=False)
# Out:
# page number 50 is completed
# page number 51 is completed
# page number 52 is completed
# page number 53 is completed
# page number 54 is completed
# page number 55 is completed
# page number 56 is completed
# page number 57 is completed
# page number 58 is completed
# page number 59 is completed
# page number 60 is completed
# page number 61 is completed
# page number 62 is completed
# page number 63 is completed
# page number 64 is completed
# page number 65 is completed
# page number 66 is completed
# page number 67 is completed
# page number 68 is completed
# page number 69 is completed
# page number 70 is completed
# page number 71 is completed
# page number 72 is completed
# page number 73 is completed
# page number 74 is completed
# page number 75 is completed
# page number 76 is completed
# page number 77 is completed
# page number 78 is completed
# page number 79 is completed
# page number 80 is completed
# page number 81 is completed
# page number 82 is completed
# ...

# %%
final_df_2.head()
# Out:
#   article_id                                              Claim  \
# 0      20950  নারী ক্রোমোজোমকে বোঝাতে ভুল প্রতীক তুলে ধরা হয়েছে
# 1      20947   জাপানের আকাশে দেখা গেছে এমন অদ্ভুত আকৃতির এই মেঘ
# 2      20942  যুক্তরাষ্ট্রের এমআইটিতে ২৪ কোটি ৩৩ লাখ টাকার শ...
# 3      20911  ❝সাঈদী হুজুর ❞ জেলখানায় ভীষণ অসুস্থ 😭  ওনার জন...
# 4      20910     প্রধানমন্ত্রী শেখ হাসিনা সিঁদুর পরানোর মুহুর্ত
#
#       Claimed_by  Fact Check
# 0  Facebook Post       False
# 1  Facebook Post  Misleading
# 2  Facebook Post  Misleading
# 3  Facebook post       False
# 4  Facebook Post       False

# %%
len(final_df_2)
# Out:
# 583

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import lxml

final_df_3=pd.DataFrame()

for i in range(100,159):
    url=f'https://www.boombd.com/fake-news/{i}'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'lxml')

    link_heads=soup.find_all('h4')
    #print(link_heads)

    links=[]
    article_id=[]
    for link_head in link_heads:
        tem_link=link_head.a['href']
        match = re.search(r'\D(\d+)$', tem_link)
        if match:
            number = match.group(1)
        article_id.append(number)
        links.append(tem_link)

    #print(links)
    #print(article_id)

    news=[]
    for link in links:
        match = re.search(r'\D(\d+)$', link)
        if match:
            article_id = match.group()
            match = re.search(r'(\d+)', article_id)
            if match:
                article_id = match.group()
        url= "https://www.boombd.com/" + link
        response=requests.get(url)
        response=response.content
        soup=BeautifulSoup(response,'lxml')
        # data_div=soup.find('div', class_='claim-review-block mt-40 mb-40')
        datas=soup.find_all('span', class_='value')
        value=[]
        for data in datas:
            value.append(data.text)
        length=len(value)
        if length==3:
            claim=value[0]
            clamied_by=value[1]
            Fact_check=value[2]
            news.append([article_id,claim,clamied_by,Fact_check])

        else:
            continue
    temp_df = pd.DataFrame(news, columns=['article_id','Claim','Claimed_by', 'Fact Check'])

    final_df_3=pd.concat([final_df_3, temp_df],axis=0)
    del temp_df
    print(f'page number {i} is completed')
    if i%10==0:
        final_df_3.to_csv('final_df_3.csv',index=False)


final_df_3.to_csv('final_df_3.csv',index=False)
# Out:
# page number 100 is completed
# page number 101 is completed
# page number 102 is completed
# page number 103 is completed
# page number 104 is completed
# page number 105 is completed
# page number 106 is completed
# page number 107 is completed
# page number 108 is completed
# page number 109 is completed
# page number 110 is completed
# page number 111 is completed
# page number 112 is completed
# page number 113 is completed
# page number 114 is completed
# page number 115 is completed
# page number 116 is completed
# page number 117 is completed
# page number 118 is completed
# page number 119 is completed
# page number 120 is completed
# page number 121 is completed
# page number 122 is completed
# page number 123 is completed
# page number 124 is completed
# page number 125 is completed
# page number 126 is completed
# page number 127 is completed
# page number 128 is completed
# page number 129 is completed
# page number 130 is completed
# page number 131 is completed
# ...

# %%
len(final_df_3)
# Out:
# 692

# %%
final_df_3.head()
# Out:
#   article_id                                              Claim  \
# 0      15441  ভারতের একটি ছোট্ট অঙ্গরাজ্য ত্রিপুরা। ত্রিপুরা...
# 1      15421  তিন তালাক এবং বহুবিবাহ থেকে বাচাতে নিজের মেয়েক...
# 2      15420  #ত্রিপুরা_চুরাইবাড়ীতে ধর্মপ্রাণ মুসলমানদের বি...
# 3      15419  https://www.facebook.com/bivash.das.359/posts/...
# 4      15389  মেয়ে নয়, এবার বলিউড কাঁপাতে আসছেন আমির খানের ভ...
#
#        Claimed_by  Fact Check
# 0  Facebook Posts       False
# 1  Facebook Posts       False
# 2  Facebook Posts       False
# 3  Facebook Posts       False
# 4  Facebook Posts  Misleading

# %%
url=f'https://www.boombd.com/fake-news'
response=requests.get(url)
response=response.content
soup=BeautifulSoup(response,'lxml')

link_heads=soup.find_all('h4')
    #print(link_heads)
links=[]
article_id=[]
for link_head in link_heads:
    tem_link=link_head.a['href']
    match = re.search(r'\D(\d+)$', tem_link)
    if match:
        number = match.group(1)
        article_id.append(number)
        links.append(tem_link)

print(links)
print(article_id)

news=[]
for link in links:
    match = re.search(r'\D(\d+)$', link)
    if match:
        article_id = match.group()

    match = re.search(r'(\d+)', article_id)
    if match:
        article_id = match.group()
    url= "https://www.boombd.com/" + link
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'lxml')
    # data_div=soup.find('div', class_='claim-review-block mt-40 mb-40')
    datas=soup.find_all('span', class_='value')
    print(datas)
    value=[]
    for data in datas:
        print(data)
        value.append(data.text)

    length=len(value)
    if length==3:
        claim=value[0]
        clamied_by=value[1]
        Fact_check=value[2]
        #print(f' artical_id : {article_id} claim : {claim}, clamied_by: {clamied_by}, Fact check: {Fact_check}')
        news.append([article_id,claim,clamied_by,Fact_check])
        # print(news)
    else:
        continue
page_df1 = pd.DataFrame(news, columns=['article_id','Claim','Claimed_by', 'Fact Check'])
# Out:
# ['/fake-news/spreading-baseless-information-about-a-student-protesting-in-buet-24822', '/fake-news/allah-written-image-frame-in-ronaldos-hand-has-been-edited-and-placed-24786', '/fake-news/the-picture-circulated-claiming-to-be-full-moon-image-is-edited-24785', '/fake-news/open-universitys-hsc-exam-fake-routine-promoted-on-facebook-24784', '/fake-news/the-viral-photo-is-not-of-the-youth-interviewed-at-the-holi-festival-24783', '/fake-news/propaganda-of-fake-claim-of-giving-15-thousand-taka-to-each-person-with-presidents-picture-24782', '/fake-news/spreading-misleading-information-about-fasting-in-the-name-of-japanese-scientist-yoshinori-osumi-24781', '/fake-news/pathirana-did-not-take-blessings-by-touching-dhonis-feet-on-the-field-24773', '/fake-news/the-demand-of-bkash-customers-to-give-rs-7999-salami-on-the-occasion-of-eid-is-baseless-24772', '/fake-news/fake-claim-of-pharaohs-mummy-talking-spread-on-facebook-24771', '/fake-news/spreading-misinformation-using-snopes-name-24759', '/f
# ...

# %%
page_df1.head()
# Out:
#   article_id                                              Claim  \
# 0      24822  বুয়েট আন্দোলনে নেতৃত্ব দেওয়া নারী শিক্ষার্থী প...
# 1      24786      রোনালদো 'আল্লাহ' লেখা ফ্রেম নিজ হাতে ধরে আছেন
# 2      24785  ক্যালিফোর্নিয়া, মার্কিন যুক্তরাষ্ট্রের সেন্টি...
# 3      24784        এইচএসসি পরীক্ষা ২০২৪ এর রুটিন প্রকাশ। (ছবি)
# 4      24783  শিক্ষার্থীদের হাতে গণধো*লাই খেলো রঙ খেলায় উস্ক...
#
#       Claimed_by Fact Check
# 0  Facebook Post      False
# 1  Facebook Post      False
# 2  Facebook post      False
# 3  Facebook post      False
# 4  Facebook Post      False

# %%
len(page_df1)
# Out:
# 12

# %%
page_df1.to_csv('page_df1.csv',index=False)

# %%
final_df_fake=pd.concat([page_df1, final_df_1, final_df_2,final_df_3],axis=0)

final_df_fake.to_csv('final_df_fake.csv', index=False)

# %%
len(final_df_fake)
# Out:
# 1856

# %%
final_df_fake.head()
# Out:
#   article_id                                              Claim  \
# 0      24822  বুয়েট আন্দোলনে নেতৃত্ব দেওয়া নারী শিক্ষার্থী প...
# 1      24786      রোনালদো 'আল্লাহ' লেখা ফ্রেম নিজ হাতে ধরে আছেন
# 2      24785  ক্যালিফোর্নিয়া, মার্কিন যুক্তরাষ্ট্রের সেন্টি...
# 3      24784        এইচএসসি পরীক্ষা ২০২৪ এর রুটিন প্রকাশ। (ছবি)
# 4      24783  শিক্ষার্থীদের হাতে গণধো*লাই খেলো রঙ খেলায় উস্ক...
#
#       Claimed_by Fact Check
# 0  Facebook Post      False
# 1  Facebook Post      False
# 2  Facebook post      False
# 3  Facebook post      False
# 4  Facebook Post      False

# %% [markdown]
# ## Authentic news collection recent just headline

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import lxml

# %%
url='https://www.somoynews.tv/categories/%E0%A6%AC%E0%A6%BE%E0%A6%82%E0%A6%B2%E0%A6%BE%E0%A6%A6%E0%A7%87%E0%A6%B6'
response=requests.get(url)
print(response)
response=response.content
soup=BeautifulSoup(response,'lxml')
link=soup.find_all('div',class_= 'row ma-0 mt-4 mt-md-0 px-0 px-md-16 px-lg-13 mx-0 mx-md-1 mx-lg-16')
print(link)
# Out:
# <Response [403]>
# []

# %%
# !pip install autoscraper

# %%
from autoscraper import AutoScraper

url = 'https://www.somoynews.tv/categories/বাংলাদেশ'

# We can add one or multiple candidates here.
# You can also put urls here to retrieve urls.
wanted_list = [ "এশিয়ার সর্ববৃহৎ ঈদ জামাত সকাল ৯টায়" ]

scraper = AutoScraper ( )

result = scraper.build(url, wanted_list)
print(result)
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup

# URL of the website to scrape
url = "https://www.somoynews.tv/categories/%E0%A6%AC%E0%A6%BE%E0%A6%82%E0%A6%B2%E0%A6%BE%E0%A6%A6%E0%A7%87%E0%A6%B6"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the elements containing news headlines
    headlines = soup.find_all('h2', class_='tv-medium-font')

    # Extract and print the headlines
    for headline in headlines:
        print(headline.text.strip())
else:
    print("Failed to retrieve the webpage.")

# %%
import requests

def check_robots_txt(url):
    try:
        robots_url = url + "/robots.txt"
        response = requests.get(robots_url)
        if response.status_code == 200:
            print(response.text)
        else:
            print("Failed to retrieve robots.txt. Status code:", response.status_code)
    except Exception as e:
        print("An error occurred:", e)

# Example usage:
check_robots_txt("https://www.somoynews.tv")
# Out:
# User-agent: *
# Disallow: /cgi-bin/
# Disallow: /app/
# Allow: /
# Sitemap: https://www.somoynews.tv/index-sitemap.xml

# %%
import requests
from bs4 import BeautifulSoup
import time

def scrape_somoy_news():
    # URL of the website to scrape
    url = "https://www.somoynews.tv/categories/বাংলাদেশ"

    # Send a GET request to the URL with a custom User-Agent
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(url, headers=headers)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all h4 tags containing news headlines
        headlines = soup.find_all('h4')

        # Extract and print the headlines
        for headline in headlines:
            print(headline.text.strip())

    else:
        print("Failed to retrieve the webpage.")

def main():
    # Check the robots.txt file for permission
    robots_url = "https://www.somoynews.tv/robots.txt"
    response = requests.get(robots_url)
    if response.status_code == 200:
        print("Robots.txt content:")
        print(response.text)
    else:
        print("Failed to retrieve robots.txt. Status code:", response.status_code)

    # Scrape the website respecting guidelines
    scrape_somoy_news()

if __name__ == "__main__":
    main()
# Out:
# Robots.txt content:
# User-agent: *
# Disallow: /cgi-bin/
# Disallow: /app/
# Allow: /
# Sitemap: https://www.somoynews.tv/index-sitemap.xml

# %%
import requests
from bs4 import BeautifulSoup
import time

def scrape_somoy_news():
    # URL of the website to scrape
    url = "https://www.somoynews.tv/categories/বাংলাদেশ"

    # Send a GET request to the URL with a custom User-Agent
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(url, headers=headers)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all h4 tags containing news headlines
        headlines = soup.find_all('h4')
        print(headlines)

        # Extract and print the headlines
        if headlines:
            for headline in headlines:
                print(headline.text.strip())
        else:
            print("No headlines found on the page.")

    else:
        print("Failed to retrieve the webpage.")

def main():
    # Check the robots.txt file for permission
    robots_url = "https://www.somoynews.tv/robots.txt"
    response = requests.get(robots_url)
    if response.status_code == 200:
        print("Robots.txt content:")
        print(response.text)
    else:
        print("Failed to retrieve robots.txt. Status code:", response.status_code)

    # Scrape the website respecting guidelines
    scrape_somoy_news()

if __name__ == "__main__":
    main()
# Out:
# Robots.txt content:
# User-agent: *
# Disallow: /cgi-bin/
# Disallow: /app/
# Allow: /
# Sitemap: https://www.somoynews.tv/index-sitemap.xml
# []
# No headlines found on the page.

# %%
url='https://www.youtube.com/@somoynews360/videos'
response=requests.get(url)
print(response)
response=response.content
soup=BeautifulSoup(response,'lxml')
link=soup.find('a',class_='yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media')
print(link)
title=link.find('a',class_='yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media')
print(title)
# Out:
# <Response [200]>
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-9656f3e28e15> in <cell line: 8>()
#       6 link=soup.find('a',class_='yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media')
#       7 print(link)
# ----> 8 title=link.find('a',class_='yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media')
#       9 print(title)
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %% [markdown]
# # From youtube

# %%
# !pip install google-api-python-client

# %%
api_youtube='AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

# %%
from googleapiclient.discovery import build

api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

youtube = build('youtube', 'v3', developerKey=api_key)

request = youtube.channels().list(
        part='statistics',
        forUsername='schafer5'
    )

response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': '24SROJ7BF_5C6gsRV5oNfjQP6j4', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'o_2kbC7pzJJC1VB-CJqaFPz5S9U', 'id': 'UCCezIgC97PvUuR4_gbFUs5g', 'statistics': {'viewCount': '94151733', 'subscriberCount': '1290000', 'hiddenSubscriberCount': False, 'videoCount': '233'}}]}

# %%
from googleapiclient.discovery import build

def get_video_titles_from_channel(api_key, channel_id):
    youtube = build('youtube', 'v3', developerKey=api_key)

    request = youtube.search().list(
        channelId=channel_id,
        part='snippet',
        type='video',
        maxResults=50  # Adjust as needed
    )

    response = request.execute()

    titles = [item['snippet']['title'] for item in response['items']]
    return titles

def main():
    # Replace 'YOUR_API_KEY' with your actual API key
    api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

    # Replace 'CHANNEL_ID' with the ID of the channel you want to retrieve videos from
    channel_id = 'UCxHoBXkY88Tb8z1Ssj6CWsQ'

    video_titles = get_video_titles_from_channel(api_key, channel_id)
    for title in video_titles:
        print(title)

if __name__ == "__main__":
    main()
# Out:
# পুলিশের পা ধরেও মিলল না ক্ষমা, ৫০০০ টাকা জরিমানা! #bangladeshpolice #viralvideo #somoytv #shorts
# কিশোর গ্যাংয়ের হামলা, সিসি টিভি ফুটেজে ধরা! #kishorgang #police #dhakanews #somoytv #shorts
# কুকি-চিন দমনে ঢাকা থেকে বান্দরবানে এপিবিএন! #kukichin #knf #apbn #bandarban #somoytv #shorts
# ৩ সেকেন্ডে বদলে যায় ফোনের আইএমইআই নম্বর! #imeichange #rab #rabbrief #crimenews #somoytv #shorts
# ৩ ফসলি কৃষিজমি বালু ফেলে ভরাট করছে কারা? #narsingdinews #sand #somoytv #shorts
# হঠাৎ কেন বান্দরবানে সেনাপ্রধান #armychief #kukichin #knf #bandarban #somoytv #shorts
# বিশ্ব বাজারে স্বর্ণের দামে নতুন রেকর্ড #goldprice #goldmarket #gold #business #somoytv #shorts
# দিনে-দুপুরে প্রকাশ্যে রাস্তার রেলিং চুরি! #theif #dhaka #shorts #reels #somoytv
# প্রতিদিন বিক্রি করেন ৬০ হাজার টাকার শরবত! #sorbotemohabbat #lalmia #colddrinks #shorts #somoytv
# মসজিদ করেছি, এখন চক্ষু হাসপাতাল করব: রোজিনা #rozina #bdactress #interview #somoytv #shorts
# ...

# %%
import pandas as pd
from googleapiclient.discovery import build

def get_video_titles(api_key, channel_id, max_results=50, total_results=2000):
    youtube = build('youtube', 'v3', developerKey=api_key)

    video_titles = []
    next_page_token = None
    total_collected = 0

    while total_collected < total_results:
        request = youtube.search().list(
            channelId=channel_id,
            part='snippet',
            type='video',
            maxResults=min(max_results, total_results - total_collected),
            pageToken=next_page_token
        )

        response = request.execute()

        for item in response['items']:
            title = item['snippet']['title']
            # Discard hashtags
            title = title.replace('#', '')
            video_titles.append(title)
            total_collected += 1

            if total_collected >= total_results:
                break

        if 'nextPageToken' in response:
            next_page_token = response['nextPageToken']
        else:
            break

    return video_titles

def main():
    # Replace 'YOUR_API_KEY' with your actual API key
    api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

    # Replace 'CHANNEL_ID' with the ID of the channel you want to retrieve videos from
    channel_id = 'UCxHoBXkY88Tb8z1Ssj6CWsQ'

    video_titles = get_video_titles(api_key, channel_id, total_results=2000)

    # Create DataFrame
    df = pd.DataFrame(video_titles, columns=['Heading'])
    print(df)

if __name__ == "__main__":
    main()
# Out:
#                                                Heading
# 0    পুলিশের পা ধরেও মিলল না ক্ষমা, ৫০০০ টাকা জরিমা...
# 1    কিশোর গ্যাংয়ের হামলা, সিসি টিভি ফুটেজে ধরা! k...
# 2    কুকি-চিন দমনে ঢাকা থেকে বান্দরবানে এপিবিএন! ku...
# 3    ৩ সেকেন্ডে বদলে যায় ফোনের আইএমইআই নম্বর! imeic...
# 4    ৩ ফসলি কৃষিজমি বালু ফেলে ভরাট করছে কারা? narsi...
# ..                                                 ...
# 596  শ্রীলঙ্কার অর্থনৈতিক মন্দা: ভারতের সরকারবিরোধী...
# 597  ইউক্রেন রাশিয়া যুদ্ধঃ যেভাবে বিশ্বকে বোকা বানা...
# 598  ইউক্রেনকে এবার দূরপাল্লার ক্ষেপণাস্ত্র দিচ্ছে ...
# 599  ইসরাইলকে বাঁ-চা-র জন্য ৩৬৫ দিনের সময় বেঁধে দেয়...
# 600  সানি লিওনের মতই হুবুহু দেখতে আভিরা | Aaveera S...
#
# [601 rows x 1 columns]

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-c42a15b2c7cf> in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from googleapiclient.discovery import build

def get_video_titles(api_key, channel_id, max_results=60, total_results=2000):
    youtube = build('youtube', 'v3', developerKey=api_key)

    video_titles = []
    next_page_token = None
    total_collected = 0

    while total_collected < total_results:
        request = youtube.search().list(
            channelId=channel_id,
            part='snippet',
            type='video',
            maxResults=min(max_results, total_results - total_collected),
            pageToken=next_page_token
        )

        response = request.execute()

        for item in response['items']:
            title = item['snippet']['title']
            # Discard hashtags
            title = title.replace('#', '')
            video_titles.append(title)
            total_collected += 1

            if total_collected >= total_results:
                break

        if 'nextPageToken' in response:
            next_page_token = response['nextPageToken']
        else:
            break

    return video_titles

def main():
    # Replace 'YOUR_API_KEY' with your actual API key
    api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

    # Replace 'CHANNEL_ID' with the ID of the channel you want to retrieve videos from
    channel_id = 'UCxHoBXkY88Tb8z1Ssj6CWsQ'

    video_titles = get_video_titles(api_key, channel_id, total_results=2000)

    # Create DataFrame
    data_frame = pd.DataFrame(video_titles, columns=['Title'])
    print(data_frame)

    return data_frame

if __name__ == "__main__":
    data_frame = main()
# Out:
#                                                  Title
# 0    পুলিশের পা ধরেও মিলল না ক্ষমা, ৫০০০ টাকা জরিমা...
# 1    কিশোর গ্যাংয়ের হামলা, সিসি টিভি ফুটেজে ধরা! k...
# 2    কুকি-চিন দমনে ঢাকা থেকে বান্দরবানে এপিবিএন! ku...
# 3    ৩ সেকেন্ডে বদলে যায় ফোনের আইএমইআই নম্বর! imeic...
# 4    ৩ ফসলি কৃষিজমি বালু ফেলে ভরাট করছে কারা? narsi...
# ..                                                 ...
# 596  শ্রীলঙ্কার অর্থনৈতিক মন্দা: ভারতের সরকারবিরোধী...
# 597  ইউক্রেন রাশিয়া যুদ্ধঃ যেভাবে বিশ্বকে বোকা বানা...
# 598  ইউক্রেনকে এবার দূরপাল্লার ক্ষেপণাস্ত্র দিচ্ছে ...
# 599  ইসরাইলকে বাঁ-চা-র জন্য ৩৬৫ দিনের সময় বেঁধে দেয়...
# 600  সানি লিওনের মতই হুবুহু দেখতে আভিরা | Aaveera S...
#
# [601 rows x 1 columns]

# %%
data_frame.head()
# Out:
#                                                Title
# 0  পুলিশের পা ধরেও মিলল না ক্ষমা, ৫০০০ টাকা জরিমা...
# 1  কিশোর গ্যাংয়ের হামলা, সিসি টিভি ফুটেজে ধরা! k...
# 2  কুকি-চিন দমনে ঢাকা থেকে বান্দরবানে এপিবিএন! ku...
# 3  ৩ সেকেন্ডে বদলে যায় ফোনের আইএমইআই নম্বর! imeic...
# 4  ৩ ফসলি কৃষিজমি বালু ফেলে ভরাট করছে কারা? narsi...

# %%
len(data_frame)
# Out:
# 601

# %%
data_frame.iloc[2,0]
# Out:
# 'কুকি-চিন দমনে ঢাকা থেকে বান্দরবানে এপিবিএন! kukichin knf apbn bandarban somoytv shorts'

# %%
import pandas as pd
from googleapiclient.discovery import build

def get_video_titles(api_key, channel_id, max_results=50, total_results=2000):
    youtube = build('youtube', 'v3', developerKey=api_key)

    video_titles = []
    next_page_token = None
    total_collected = 0

    while total_collected < total_results:
        request = youtube.videos().list(
            part='snippet',
            maxResults=min(max_results, total_results - total_collected),
            pageToken=next_page_token,
            channelId=channel_id
        )

        response = request.execute()

        for item in response['items']:
            title = item['snippet']['title']
            # Discard hashtags
            title = title.replace('#', '')
            video_titles.append(title)
            total_collected += 1

            if total_collected >= total_results:
                break

        if 'nextPageToken' in response:
            next_page_token = response['nextPageToken']
        else:
            break

    return video_titles

def main():
    # Replace 'YOUR_API_KEY' with your actual API key
    api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

    # Replace 'CHANNEL_ID' with the ID of the channel you want to retrieve videos from
    channel_id = 'UCxHoBXkY88Tb8z1Ssj6CWsQ'

    video_titles = get_video_titles(api_key, channel_id, total_results=2000)

    # Create DataFrame
    data_frame = pd.DataFrame(video_titles, columns=['Title'])
    print(data_frame)

    return data_frame

if __name__ == "__main__":
    data_frame = main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-b8089099e012> in <cell line: 53>()
#      52
#      53 if __name__ == "__main__":
# ---> 54     data_frame = main()
#
# <ipython-input-27-b8089099e012> in main()
#      43     channel_id = 'UCxHoBXkY88Tb8z1Ssj6CWsQ'
#      44
# ---> 45     video_titles = get_video_titles(api_key, channel_id, total_results=2000)
#      46
#      47     # Create DataFrame
#
# <ipython-input-27-b8089099e012> in get_video_titles(api_key, channel_id, max_results, total_results)
#      10
#      11     while total_collected < total_results:
# ---> 12         request = youtube.videos().list(
#      13             part='snippet',
#      14             maxResults=min(max_results, total_results - total_collected),
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/discovery.py in method(self, **kwargs)
# ...

# %%
import pandas as pd
from googleapiclient.discovery import build

def get_video_titles(api_key, channel_id, max_results=50, total_results=2000):
    youtube = build('youtube', 'v3', developerKey=api_key)

    video_titles = []
    next_page_token = None
    total_collected = 0

    while total_collected < total_results:
        request = youtube.search().list(
            part='snippet',
            maxResults=min(max_results, total_results - total_collected),
            pageToken=next_page_token,
            channelId=channel_id,
            type='video'
        )

        response = request.execute()

        for item in response['items']:
            title = item['snippet']['title']
            # Discard hashtags
            title = title.replace('#', '')
            video_titles.append(title)
            total_collected += 1

            if total_collected >= total_results:
                break

        if 'nextPageToken' in response:
            next_page_token = response['nextPageToken']
        else:
            break

    return video_titles

def main():
    # Replace 'YOUR_API_KEY' with your actual API key
    api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

    # Replace 'CHANNEL_ID' with the ID of the channel you want to retrieve videos from
    channel_id = 'UCxHoBXkY88Tb8z1Ssj6CWsQ'

    video_titles = get_video_titles(api_key, channel_id, total_results=2000)

    # Create DataFrame
    data_frame = pd.DataFrame(video_titles, columns=['Title'])
    print(data_frame)

    return data_frame

if __name__ == "__main__":
    data_frame = main()
# Out:
#                                                  Title
# 0    পুলিশের পা ধরেও মিলল না ক্ষমা, ৫০০০ টাকা জরিমা...
# 1    কিশোর গ্যাংয়ের হামলা, সিসি টিভি ফুটেজে ধরা! k...
# 2    কুকি-চিন দমনে ঢাকা থেকে বান্দরবানে এপিবিএন! ku...
# 3    ৩ সেকেন্ডে বদলে যায় ফোনের আইএমইআই নম্বর! imeic...
# 4    ৩ ফসলি কৃষিজমি বালু ফেলে ভরাট করছে কারা? narsi...
# ..                                                 ...
# 596  শ্রীলঙ্কার অর্থনৈতিক মন্দা: ভারতের সরকারবিরোধী...
# 597  ইউক্রেনকে এবার দূরপাল্লার ক্ষেপণাস্ত্র দিচ্ছে ...
# 598  ইসরাইলকে বাঁ-চা-র জন্য ৩৬৫ দিনের সময় বেঁধে দেয়...
# 599  ইউক্রেন রাশিয়া যুদ্ধঃ যেভাবে বিশ্বকে বোকা বানা...
# 600  সানি লিওনের মতই হুবুহু দেখতে আভিরা | Aaveera S...
#
# [601 rows x 1 columns]

# %% [markdown]
# # tutorial Calculating The Duration Of a Playlist

# %%
import os
from googleapiclient.discovery import build

api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

youtube = build('youtube', 'v3', developerKey=api_key)

pl_request = youtube.playlists().list(
        part='contentDetails, snippet ',
        channelId='UCxHoBXkY88Tb8z1Ssj6CWsQ'
    )

pl_response = pl_request.execute()

for item in pl_response['items']:
    print(item)
# Out:
# {'kind': 'youtube#playlist', 'etag': 'N_BbB-Z6P0Cz8epDU-IoqXgJbkw', 'id': 'PLlpG3KtmKKzwTXRUSQvj22ZA5hADOS1BP', 'snippet': {'publishedAt': '2024-03-21T13:15:42Z', 'channelId': 'UCxHoBXkY88Tb8z1Ssj6CWsQ', 'title': 'দেশজুড়ে পবিত্র স্থান', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ANIkqu2ccFQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/ANIkqu2ccFQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/ANIkqu2ccFQ/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/ANIkqu2ccFQ/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/ANIkqu2ccFQ/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'SOMOY TV', 'localized': {'title': 'দেশজুড়ে পবিত্র স্থান', 'description': ''}}, 'contentDetails': {'itemCount': 19}}
# ...

# %%
import os
from googleapiclient.discovery import build

api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

youtube = build('youtube', 'v3', developerKey=api_key)

pl_request = youtube.playlistItems().list(
        part='contentDetails',
        playlistId='PLlpG3KtmKKzwTXRUSQvj22ZA5hADOS1BP'
    )

pl_response = pl_request.execute()


vid_ids=[]
for item in pl_response['items']:
    vid_ids.append(item['contentDetails']['videoId'])

print(','.join(vid_ids))


vid_request=youtube.videos().list(
    part='contentDetails',
    id=','.join(vid_ids)
)

vid_response=vid_request.execute()

for item in vid_response['items']:
    print(item)
    print()
# Out:
# ANIkqu2ccFQ,uJcfWlo-b6w,uV8iK-9gZkU,dSxBlGIMASI,RPo_DYp942U
# {'kind': 'youtube#video', 'etag': 'bhqboAxum9uAd_mna4XqcCCxdyc', 'id': 'ANIkqu2ccFQ', 'contentDetails': {'duration': 'PT3M26S', 'dimension': '2d', 'definition': 'hd', 'caption': 'false', 'licensedContent': True, 'contentRating': {}, 'projection': 'rectangular'}}
#
# {'kind': 'youtube#video', 'etag': 'VfIlE8a--i69j2zDri9tQwVJlCc', 'id': 'uJcfWlo-b6w', 'contentDetails': {'duration': 'PT3M2S', 'dimension': '2d', 'definition': 'hd', 'caption': 'false', 'licensedContent': True, 'contentRating': {}, 'projection': 'rectangular'}}
#
# {'kind': 'youtube#video', 'etag': 'sA5J9pZkUzkaFIBI9hIJj3CMwck', 'id': 'uV8iK-9gZkU', 'contentDetails': {'duration': 'PT2M56S', 'dimension': '2d', 'definition': 'hd', 'caption': 'false', 'licensedContent': True, 'contentRating': {}, 'projection': 'rectangular'}}
#
# ...

# %%
import re
from datetime import timedelta
import os
from googleapiclient.discovery import build

api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

youtube = build('youtube', 'v3', developerKey=api_key)

hours_pattern = re.compile(r'(\d+)H')
minutes_pattern = re.compile(r'(\d+)M')
seconds_pattern = re.compile(r'(\d+)s')

total_seconds = 0

nextPageToken = None

while True:
    pl_request = youtube.playlistItems().list(
            part='contentDetails',
            playlistId='PLlpG3KtmKKzwTXRUSQvj22ZA5hADOS1BP',
            maxResults=50,
            pageToken=nextPageToken
        )

    pl_response = pl_request.execute()


    vid_ids=[]
    for item in pl_response['items']:
        vid_ids.append(item['contentDetails']['videoId'])


    # vid_request=youtube.videos().list(
    #     part='contentDetails',
    #     id=','.join(vid_ids)
    # )

    # vid_response=vid_request.execute()

    # for item in vid_response['items']:
    #     print(item)
    #     print()

    vid_request=youtube.videos().list(
        part='contentDetails',
        id=','.join(vid_ids)
    )

    vid_response=vid_request.execute()



    for item in vid_response['items']:

        duration=item['contentDetails']['duration']

        hours=hours_pattern.search(duration)
        minutes=minutes_pattern.search(duration)
        seconds=seconds_pattern.search(duration)

        hours=int(hours.group(1)) if hours else 0
        minutes= int(minutes.group(1)) if minutes else 0
        seconds=int(seconds.group(1)) if seconds else 0

        video_seconds =timedelta(
            hours=hours,
            minutes= minutes,
            seconds=seconds
        ).total_seconds()


        total_seconds +=video_seconds

    nextPageToken=pl_response.get('nextPageToken')

    if not nextPageToken:
        break

total_seconds=int(total_seconds)
minutes, seconds = divmod(total_seconds, 60)
hours , minutes=divmod(minutes, 60)
print(f'This playlist take total time of {hours}:{minutes}:{seconds}')
# Out:
# This playlist take total time of 0:56:0

# %% [markdown]
# ## python Youtube API : Sort a playlist by Most Popular Videos

# %%
import os
from googleapiclient.discovery import build

api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

youtube = build('youtube', 'v3', developerKey=api_key)




Playlist_id='PLsRNoUx8w3rOB98F3pbZOLeRaG3XOMpQd'


videos =[]

nextPageToken = None

while True:
    pl_request = youtube.playlistItems().list(
            part='contentDetails',
            playlistId=Playlist_id,
            maxResults=50,
            pageToken=nextPageToken
        )

    pl_response = pl_request.execute()


    vid_ids=[]
    for item in pl_response['items']:
        vid_ids.append(item['contentDetails']['videoId'])

    vid_request=youtube.videos().list(
        part='statistics',
        id=','.join(vid_ids)
    )

    vid_response=vid_request.execute()



    for item in vid_response['items']:
        vid_views=item['statistics']['viewCount']

        vid_id=item['id']
        yt_link=f'https://youtu.be/{vid_id}'

        videos.append(
            {
                'views':int(vid_views),
                'url' :yt_link
            }
        )


    nextPageToken=pl_response.get('nextPageToken')

    if not nextPageToken:
        break

videos.sort(key=lambda vid:vid['views'],reverse=True)

for video in videos[:10]:
    print(video['url'], video['views'])
# Out:
# https://youtu.be/sKvMxZ284AA 18189421
# https://youtu.be/t9fP_b8Ebow 11727884
# https://youtu.be/LKPD_a4xd7M 8053714
# https://youtu.be/p5N_a5htoNQ 3429315
# https://youtu.be/koW46mlX4VM 2576386
# https://youtu.be/ZWKCY0HgXkA 2096236
# https://youtu.be/cCoj-Ho1cic 1831754
# https://youtu.be/lGJoaVHYifU 1826381
# https://youtu.be/9mVlAzX55HU 1777085
# https://youtu.be/MH3SRXuF634 1690035

# %% [markdown]
# # dataset collect

# %%
playlist_links=['PLlpG3KtmKKzzChGab4JUM7JGWz9KmKUPL',
                'PLlpG3KtmKKzzgg37Ruc4IesyJCAO4FuJQ',
                'PLlpG3KtmKKzzfId3gk467G_sitkChGALt',
                'PLlpG3KtmKKzxy0swkVh3YVFiCEe7BeAHD',
                'PLlpG3KtmKKzzJf8vnKngk-THe_pUiCZoS',
                'PLlpG3KtmKKzz05TZOSF_aNA3MpSKLUrKW',
                'PLlpG3KtmKKzyvCdGhqlM0qJtQ5g98avEv']

# %%
import pandas as pd

import re
import os
from googleapiclient.discovery import build

api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

youtube = build('youtube', 'v3', developerKey=api_key)

pattern=re.compile(r'(.+?)\|')

data=[]
playlist_links=['PLlpG3KtmKKzzChGab4JUM7JGWz9KmKUPL',
                'PLlpG3KtmKKzzgg37Ruc4IesyJCAO4FuJQ',
                'PLlpG3KtmKKzzfId3gk467G_sitkChGALt',
                'PLlpG3KtmKKzxy0swkVh3YVFiCEe7BeAHD',
                'PLlpG3KtmKKzzJf8vnKngk-THe_pUiCZoS',
                'PLlpG3KtmKKzz05TZOSF_aNA3MpSKLUrKW',
                'PLlpG3KtmKKzyvCdGhqlM0qJtQ5g98avEv']

for Playlist_id in playlist_links:
    nextPageToken = None
    for i in range(6):
        pl_request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=Playlist_id,
                    maxResults=50,
                    pageToken=nextPageToken
                )

        pl_response = pl_request.execute()

        vid_ids=[]

        for item in pl_response['items']:
            vid_ids.append(item['contentDetails']['videoId'])


        vid_request=youtube.videos().list(
                part='snippet',
                id=','.join(vid_ids)
            )
        vid_response=vid_request.execute()



        for item in vid_response['items']:
            news_title=item['snippet']['title']
            news_title=pattern.search(news_title)
            news_title=(news_title.group(1))if news_title else None
            vid_id=item['id']
            label='TRUE'
            news_channel='Somoy Tv'
            data.append([vid_id,news_title,news_channel,label])

        nextPageToken=pl_response.get('nextPageToken')
Auth_data_frame = pd.DataFrame(data, columns=['article_id','Claim','Claimed_by', 'Fact Check'])
len(Auth_data_frame)
# Out:
# 2087

# %%
Auth_data_frame.head()
# Out:
#     article_id                                              Claim Claimed_by  \
# 0  rzvl4kSHQSM       হঠাৎ কেন সামরিক খাতে রেকর্ড বরাদ্দ জাপানের?    Somoy Tv
# 1  eEl9rGkM-4A                   গাজার সমর্থনে সোচ্চার মালয়েশিয়া    Somoy Tv
# 2  PBdnHP63Fmk  বিমানে মানবপাচার! ভারতীয় ৩০৩ যাত্রীসহ উড়োজাহাজ...   Somoy Tv
# 3  LlUF3zC_iHo                   উৎসবের আমেজে ভাসছে যুক্তরাষ্ট্র    Somoy Tv
# 4  sMNmqFFNJ00              বড়দিন উপলক্ষে আয়ারল্যান্ডে মূল্য ছাড়    Somoy Tv
#
#   Fact Check
# 0       TRUE
# 1       TRUE
# 2       TRUE
# 3       TRUE
# 4       TRUE

# %%
Auth_data_frame.to_csv('Auth_data_frame.csv', index=False)

# %% [markdown]
# # fake news collect form https://www.jachai.org/fact-checks/page/2 this web site

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import lxml

final_df_3=pd.DataFrame()

for i in range(100,159):
    url=f'https://www.boombd.com/fake-news/{i}'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'lxml')

    link_heads=soup.find_all('h4')
    #print(link_heads)

    links=[]
    article_id=[]
    for link_head in link_heads:
        tem_link=link_head.a['href']
        match = re.search(r'\D(\d+)$', tem_link)
        if match:
            number = match.group(1)
        article_id.append(number)
        links.append(tem_link)

    #print(links)
    #print(article_id)

    news=[]
    for link in links:
        match = re.search(r'\D(\d+)$', link)
        if match:
            article_id = match.group()
            match = re.search(r'(\d+)', article_id)
            if match:
                article_id = match.group()
        url= "https://www.boombd.com/" + link
        response=requests.get(url)
        response=response.content
        soup=BeautifulSoup(response,'lxml')
        # data_div=soup.find('div', class_='claim-review-block mt-40 mb-40')
        datas=soup.find_all('span', class_='value')
        value=[]
        for data in datas:
            value.append(data.text)
        length=len(value)
        if length==3:
            claim=value[0]
            clamied_by=value[1]
            Fact_check=value[2]
            news.append([article_id,claim,clamied_by,Fact_check])

        else:
            continue
    temp_df = pd.DataFrame(news, columns=['article_id','Claim','Claimed_by', 'Fact Check'])

    final_df_3=pd.concat([final_df_3, temp_df],axis=0)
    del temp_df
    print(f'page number {i} is completed')
    if i%10==0:
        final_df_3.to_csv('final_df_3.csv',index=False)


final_df_3.to_csv('final_df_3.csv',index=False)

# %% [markdown]
# ### do in two step

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import lxml

links=[]
article_id=[]

for i in range(2,10):
    url=f'https://www.jachai.org/fact-checks/page/{i}'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'lxml')

    link_heads=soup.find_all('article', class_='list-view')

    for link_head in link_heads:
        tem_link=link_head.h2.a['href']
        match = re.search(r'\D(\d+)$', tem_link)
        if match:
            number = match.group(1)
        article_id.append(number)
        links.append(tem_link)




print(len(article_id))
print(links)
print(article_id)
# Out:
# 87
# ...

# %%
pattern_2 = r'/([^/]+)\.svg'

news=[]
for link in links:
    response=requests.get(link)
    response=response.content
    match = re.search(r'\D(\d+)$', link)
    if match:
        article_id =match.group(1) +'j'
    soup=BeautifulSoup(response,'lxml')
    title=soup.find('div', class_='post-fact-text')
    label=soup.find('div', class_='fact-status')

    if title== None:
        continue
    else:
        claim=title.text
    if label ==None:
        continue
    else:
        Fact_link=label['style']

    match = re.search(pattern_2, Fact_link)

    if match:
        Fact_check = match.group(1)
    else:
        Fact_check=None

    clamied_by='jachai'


    news.append([article_id,claim,clamied_by,Fact_check])
print(len(news))
# Out:
# 84

# %%
fake_jachai=pd.DataFrame(news, columns=['article_id','Claim','Claimed_by', 'Fact Check'])
fake_jachai.head()
# Out:
#   article_id                                              Claim Claimed_by  \
# 0      2606j  ইথানল মিশ্রিত কুসুম গরম পানি দ্বারা কুলকুচি কর...     jachai
# 1      2581j  করোনাভাইরাস সংক্রামণ রোধে, ‘কণ্ঠনালী ভেজা রাখত...     jachai
# 2      2520j  "বিমান বাংলাদেশ এয়ারলাইন্সের সদ্য ক্রয়কৃত 'আকা...     jachai
# 3      2492j  "ওয়াশিংটন ভিত্তিক ইন্টারন্যাশনাল রিপাবলিকান ইন...     jachai
# 4      2464j  "এই ছবিটি আগস্ট ৪ তারিখে ধানমন্ডিতে সাধারণ ছাত...     jachai
#
#      Fact Check
# 0         false
# 1  mostly-false
# 2         false
# 3         false
# 4         false

# %%
fake_jachai.to_csv('fake_jachai.csv', index=False)

# %% [markdown]
# # Authentic news collection
# ## ATN NEws

# %%
import pandas as pd

import re
import os
from googleapiclient.discovery import build

api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

youtube = build('youtube', 'v3', developerKey=api_key)

pattern=re.compile(r'(.+?)\|')

data=[]
playlist_links=['PLgKLpsf7f9JHz3d_Q0QcOXm5f57FWY2LG']

for Playlist_id in playlist_links:
    nextPageToken = None
    for i in range(8):
        pl_request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=Playlist_id,
                    maxResults=50,
                    pageToken=nextPageToken
                )

        pl_response = pl_request.execute()

        vid_ids=[]

        for item in pl_response['items']:
            vid_ids.append(item['contentDetails']['videoId'])


        vid_request=youtube.videos().list(
                part='snippet',
                id=','.join(vid_ids)
            )
        vid_response=vid_request.execute()



        for item in vid_response['items']:
            news_title=item['snippet']['title']
            # news_title=pattern.search(news_title)
            # news_title=(news_title.group(1))if news_title else None
            vid_id=item['id']
            label='TRUE'
            news_channel='ATN News Bangla'
            data.append([vid_id,news_title,news_channel,label])

        nextPageToken=pl_response.get('nextPageToken')
Auth_data_frame = pd.DataFrame(data, columns=['article_id','Claim','Claimed_by', 'Fact Check'])
len(Auth_data_frame)
# Out:
# 400

# %%
import pandas as pd

import re
import os
from googleapiclient.discovery import build

api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

youtube = build('youtube', 'v3', developerKey=api_key)

pattern=re.compile(r'(.+?)\|')

data=[]
playlist_links=['PL452k3Pdf5mLBs0MR8dFnXTyDZmHqBoaq',
                'PL452k3Pdf5mIkSyC4x4hV7AK80AEjhNFa']

for Playlist_id in playlist_links:
    nextPageToken = None
    for i in range(16):
        pl_request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=Playlist_id,
                    maxResults=50,
                    pageToken=nextPageToken
                )

        pl_response = pl_request.execute()

        vid_ids=[]

        for item in pl_response['items']:
            vid_ids.append(item['contentDetails']['videoId'])


        vid_request=youtube.videos().list(
                part='snippet',
                id=','.join(vid_ids)
            )
        vid_response=vid_request.execute()



        for item in vid_response['items']:
            news_title=item['snippet']['title']
            # news_title=pattern.search(news_title)
            # news_title=(news_title.group(1))if news_title else None
            vid_id=item['id']
            label='TRUE'
            news_channel='Desh TV News'
            data.append([vid_id,news_title,news_channel,label])

        nextPageToken=pl_response.get('nextPageToken')
Auth_data_frame2 = pd.DataFrame(data, columns=['article_id','Claim','Claimed_by', 'Fact Check'])
len(Auth_data_frame2)
# Out:
# 1525

# %%
Auth_data_frame.Claim
# Out:
# 0      ঈদে মাংস কিনতে না পেরে আ*ত্ম হ*ত্যা । ATN Bang...
# 1               জুমার নামাজের আগে পুড়লো মসজিদ মাদ্রাসা।
# 2      টানা তাপপ্রবাহের পর বিভিন্ন জেলায় কালবৈশাখীর ত...
# 3      সামাজিক অবক্ষয়ের কারণে গাজীপুরের কালিয়াকৈরে এক...
# 4      মস্কোর কনসার্টে হা*ম*লায় নি*হ*তের সংখ্যা বেড়ে ...
#                              ...
# 395    বন্যায় দুর্বিসহ জীবন কাটছে সিলেট শহরের বাসিন্দ...
# 396    হেলিকপ্টারে সিলেট, সুনামগঞ্জ ও নেত্রকোনার বন্য...
# 397    বন্যা পরিস্থিতির উন্নতি নেই কুড়িগ্রাম, নেত্রকো...
# 398    সিলেটের বড়াইকান্দি পাওয়ার স্টেশন রক্ষায় কাজ কর...
# 399    সিলেটের পুরান রেল স্টেশন এলাকায় বন্যার সর্বশেষ...
# Name: Claim, Length: 400, dtype: object

# %%
import pandas as pd

import re
import os
from googleapiclient.discovery import build

api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

youtube = build('youtube', 'v3', developerKey=api_key)

pattern=re.compile(r'(.+?)\|')

data=[]
playlist_links=['PLb6HuVa35CcODBXO36NwQuytCeluPlijH',
                'PLb6HuVa35CcMSUejpavLbpcszE1608b2C']

for Playlist_id in playlist_links:
    nextPageToken = None
    for i in range(16):
        pl_request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=Playlist_id,
                    maxResults=50,
                    pageToken=nextPageToken
                )

        pl_response = pl_request.execute()

        vid_ids=[]

        for item in pl_response['items']:
            vid_ids.append(item['contentDetails']['videoId'])


        vid_request=youtube.videos().list(
                part='snippet',
                id=','.join(vid_ids)
            )
        vid_response=vid_request.execute()



        for item in vid_response['items']:
            news_title=item['snippet']['title']
            # news_title=pattern.search(news_title)
            # news_title=(news_title.group(1))if news_title else None
            vid_id=item['id']
            label='TRUE'
            news_channel='ITV News'
            data.append([vid_id,news_title,news_channel,label])

        nextPageToken=pl_response.get('nextPageToken')
Auth_data_frame3 = pd.DataFrame(data, columns=['article_id','Claim','Claimed_by', 'Fact Check'])
len(Auth_data_frame3)
# Out:
# 1575

# %%
auth_data_2=pd.concat([Auth_data_frame3,Auth_data_frame2,Auth_data_frame],axis=0)

# %%
auth_data_2.head()
# Out:
#     article_id                                              Claim Claimed_by  \
# 0  vP9_k3uoFxc  বিউটি লাচ্ছির পাশের দোকানে লাগে এই আগুন | Old ...   ITV News
# 1  N4vC9sheTaU  রায়ের প্রতিক্রিয়ায় যা বললেন ড. মুহাম্মদ ইউনূস ...   ITV News
# 2  KIfecP7gN40  ভোটাররা শান্তিপূর্ণ পরিবেশে ভোট দিতে পারবেন ||...   ITV News
# 3  no-TmxuOsHI  আগামী ১০ জানুয়ারি থেকে নতুন ট্রেনটি চলাচল শুরু...   ITV News
# 4  f4gw_JvqNp4  নতুন পাঠ্যক্রমের জন্য শিক্ষকরা কি যথেষ্ট প্রশি...   ITV News
#
#   Fact Check
# 0       TRUE
# 1       TRUE
# 2       TRUE
# 3       TRUE
# 4       TRUE

# %%
import pandas as pd

import re
import os
from googleapiclient.discovery import build

api_key = 'AIzaSyDY_-_L96lBreX5MQafuIam9Qduf75Q1Jk'

youtube = build('youtube', 'v3', developerKey=api_key)

# pattern=re.compile(r'(.+?)\|')

data=[]
playlist_links=['PLlpG3KtmKKzzChGab4JUM7JGWz9KmKUPL',
                'PLlpG3KtmKKzzgg37Ruc4IesyJCAO4FuJQ',
                'PLlpG3KtmKKzzfId3gk467G_sitkChGALt',
                'PLlpG3KtmKKzxy0swkVh3YVFiCEe7BeAHD',
                'PLlpG3KtmKKzzJf8vnKngk-THe_pUiCZoS',
                'PLlpG3KtmKKzz05TZOSF_aNA3MpSKLUrKW',
                'PLlpG3KtmKKzyvCdGhqlM0qJtQ5g98avEv']

for Playlist_id in playlist_links:
    nextPageToken = None
    for i in range(6):
        pl_request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=Playlist_id,
                    maxResults=50,
                    pageToken=nextPageToken
                )

        pl_response = pl_request.execute()

        vid_ids=[]

        for item in pl_response['items']:
            vid_ids.append(item['contentDetails']['videoId'])


        vid_request=youtube.videos().list(
                part='snippet',
                id=','.join(vid_ids)
            )
        vid_response=vid_request.execute()



        for item in vid_response['items']:
            news_title=item['snippet']['title']
            # news_title=pattern.search(news_title)
            # news_title=(news_title.group(1))if news_title else None
            vid_id=item['id']
            label='TRUE'
            news_channel='Somoy Tv'
            data.append([vid_id,news_title,news_channel,label])

        nextPageToken=pl_response.get('nextPageToken')
Auth_data_frame4 = pd.DataFrame(data, columns=['article_id','Claim','Claimed_by', 'Fact Check'])
len(Auth_data_frame4)
# Out:
# 2087

# %% [markdown]
# ## data EDA

# %%
auth_data_2=pd.concat([Auth_data_frame3,Auth_data_frame2,Auth_data_frame,Auth_data_frame4],axis=0)

# %%
authd_data_row=auth_data_2.copy()
authd_data_row.to_csv('authd_data_row.csv', index=False)

# %%
auth_data_2['label']=1
auth_data_2["text"] =auth_data_2["Claim"]
auth_data_2=auth_data_2[["text","label"]]
auth_data_2.head()
# Out:
#                                                 text  label
# 0  বিউটি লাচ্ছির পাশের দোকানে লাগে এই আগুন | Old ...      1
# 1  রায়ের প্রতিক্রিয়ায় যা বললেন ড. মুহাম্মদ ইউনূস ...      1
# 2  ভোটাররা শান্তিপূর্ণ পরিবেশে ভোট দিতে পারবেন ||...      1
# 3  আগামী ১০ জানুয়ারি থেকে নতুন ট্রেনটি চলাচল শুরু...      1
# 4  নতুন পাঠ্যক্রমের জন্য শিক্ষকরা কি যথেষ্ট প্রশি...      1

# %%
! pip install bnlp_toolkit==3.3.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.5 MB/s eta 0:00:00
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171034 sha256=74e46a196eb3045cb3921e354123c343849c5bb1ea6731b5d345a090e1bf0042
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# ...

# %%
! pip install bnlp_toolkit==3.3.2

from bnlp import BasicTokenizer
from bnlp.corpus import stopwords, punctuations, letters, digits
import re
import string

btokenizer = BasicTokenizer()

def clean_text(text):


    text= re.sub(r'[A-za-z]+','',text)
    text = re.sub(r'[\U0001F300-\U0001F5FF]|[\U0001F600-\U0001F64F]|[\U0001F680-\U0001F6FF]|[\U0001F700-\U0001F77F]|[\U0001F780-\U0001F7FF]|[\U0001F800-\U0001F8FF]|[\U0001F900-\U0001F9FF]|[\U0001FA00-\U0001FA6F]|[\U0001FA70-\U0001FAFF]|[\U00002702-\U000027B0]|[\U000024C2-\U0001F251]|[\U0000203C-\U0000205F]|[\U0000200D-\U0000203F]|[\U00002000-\U0000206F]', '', text)
    text = re.sub(r'\d+', '', text)

    tokens = btokenizer.tokenize(text)
    filtered = []
    for i in tokens:
        # if i in stopwords:
        #     continue

        if i in punctuations + '‘' + '’':
            continue

        filtered.append(i)

    return " ".join(filtered)

# %%
auth_data_2.head()
# Out:
#                                                 text  label
# 0  বিউটি লাচ্ছির পাশের দোকানে লাগে এই আগুন | Old ...      1
# 1  রায়ের প্রতিক্রিয়ায় যা বললেন ড. মুহাম্মদ ইউনূস ...      1
# 2  ভোটাররা শান্তিপূর্ণ পরিবেশে ভোট দিতে পারবেন ||...      1
# 3  আগামী ১০ জানুয়ারি থেকে নতুন ট্রেনটি চলাচল শুরু...      1
# 4  নতুন পাঠ্যক্রমের জন্য শিক্ষকরা কি যথেষ্ট প্রশি...      1

# %%
auth_data_2['text'] = auth_data_2.text.apply(clean_text)
auth_data_2=auth_data_2[["text","label"]]
auth_data_2.head()
# Out:
#                                                 text  label
# 0            বিউটি লাচ্ছির পাশের দোকানে লাগে এই আগুন      1
# 1       রায়ের প্রতিক্রিয়ায় যা বললেন ড মুহাম্মদ ইউনূস      1
# 2        ভোটাররা শান্তিপূর্ণ পরিবেশে ভোট দিতে পারবেন      1
# 3   আগামী জানুয়ারি থেকে নতুন ট্রেনটি চলাচল শুরুর কথা      1
# 4  নতুন পাঠ্যক্রমের জন্য শিক্ষকরা কি যথেষ্ট প্রশি...      1

# %%
auth_data_2.shape
# Out:
# (5587, 2)

# %%
duplicate_values = auth_data_2[auth_data_2.duplicated(subset=['text'], keep=False)]
duplicate_values
# Out:
#                                                    text  label
# 320   পঞ্চগড়ে সর্বনিম্ন তাপমাত্রা দশমিক ডিগ্রি সেলসিয়াস      1
# 434   পঞ্চগড়ে সর্বনিম্ন তাপমাত্রা দশমিক ডিগ্রি সেলসিয়াস      1
# 1035  রেকর্ড পরিমাণ উৎপাদনের পরও আলু বিক্রি হচ্ছে চড়...      1
# 1040  রেকর্ড পরিমাণ উৎপাদনের পরও আলু বিক্রি হচ্ছে চড়...      1
# 1290  পাসপোর্ট ভিসা ছাড়াই বিমানে উঠে পড়লো শিশু কিন...      1
# ...                                                 ...    ...
# 1509  গাজায় হামাসের উত্থান ও ইসরাইলকে মহা চ্যালেঞ্জ ...      1
# 1510  গাজায় হামাসের উত্থান ও ইসরাইলকে মহা চ্যালেঞ্জ ...      1
# 1861      ড ইউনূসের রায় নিয়ে যা বললেন অ্যাটর্নি জেনারেল      1
# 1898                 ফুলের শুভেচ্ছায় সিক্ত কামরুল ইসলাম      1
# 1900      নতুন এমপিদের বাড়িতে বাড়িতে সাধারণ মানুষের ভিড়      1
#
# [747 rows x 2 columns]

# %%
auth_data_2.drop_duplicates(subset=['text'], keep='first', inplace=True)

# %%
auth_data_2.shape
# Out:
# (5213, 2)

# %%
df_auth_filtered = auth_data_2[auth_data_2['text'].str.split().apply(len) > 7]
df_auth_filtered.shape
# Out:
# (2432, 2)

# %%
df_auth_filtered.head()
# Out:
#                                                 text  label
# 3   আগামী জানুয়ারি থেকে নতুন ট্রেনটি চলাচল শুরুর কথা      1
# 4  নতুন পাঠ্যক্রমের জন্য শিক্ষকরা কি যথেষ্ট প্রশি...      1
# 5  ড ইউনূসের মাসের জেল এটি যুক্তরাষ্ট্র কিভাবে দেখবে      1
# 6  তুমি খালি বলবা তুমি ছক্কা মারতে পারো বল করে উই...      1
# 7  খাদ্য পণ্যের বেশি দাম দেশের শতাংশ পরিবারের জন্...      1

# %%
df_auth_filtered=df_auth_filtered[["text","label"]]
df_auth_filtered.head()
# Out:
#                                                 text  label
# 3   আগামী জানুয়ারি থেকে নতুন ট্রেনটি চলাচল শুরুর কথা      1
# 4  নতুন পাঠ্যক্রমের জন্য শিক্ষকরা কি যথেষ্ট প্রশি...      1
# 5  ড ইউনূসের মাসের জেল এটি যুক্তরাষ্ট্র কিভাবে দেখবে      1
# 6  তুমি খালি বলবা তুমি ছক্কা মারতে পারো বল করে উই...      1
# 7  খাদ্য পণ্যের বেশি দাম দেশের শতাংশ পরিবারের জন্...      1

# %%
df_auth_filtered.to_csv('df_auth_filtere_stopwards.csv', index=False)

# %%
df_auth_filtered= df_auth_filtered.sample(n=1995).reset_index(drop=True)

# %%
df_auth_filtered.to_csv('df_auth_filtere_stopwards_1995.csv', index=False)

# %%
import matplotlib.pyplot as plt



auth_data_2['words per text']=auth_data_2['text'].str.split().apply(len)
auth_data_2.boxplot('words per text', by='label',grid=False,
                 showfliers=False,color='black')

plt.suptitle('')
plt.xlabel('')
plt.show()

# %% [markdown]
# ## resourses where to learn
#
# #### Topic data collect from Youtube --->Chennel name-->Corey Schafer
# 1. https://youtu.be/th5_9woFJmk?si=SBvafPKB0TXMH4Zr
# 2. https://youtu.be/coZbOM6E47I?si=CwYoIujhgsr4oHAt
# 3. https://youtu.be/coZbOM6E47I?si=qaNVtHxgHQmbh-ay
# 4. https://youtu.be/vQQEaSnQ_bs?si=TF-P3WpvUnqJN_pf
#
# ##### Web Scrab with beautiful soup
# 1. https://youtu.be/XVv6mJpFOb0?si=_gLGMRbeuYKhW5zd --->FreeCodeCamp.org
# 2. https://youtu.be/MH3641s3Roc?si=hdRAoMubbm1XFOeS --->Pythonology
